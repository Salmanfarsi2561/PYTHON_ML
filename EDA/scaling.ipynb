# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'/workspaces/PYTHON_ML/EDA/datasets/Social_Network_Ads.csv')

# %%
df.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
print(df.shape)
print(df.columns)
# Out:
# (400, 5)
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
print(df.shape)
# Out:
# (400, 5)

# %%
df_subset = df.iloc[:,2:5]
df_subset.head(10)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0
# 5   27            58000          0
# 6   27            84000          0
# 7   32           150000          1
# 8   25            33000          0
# 9   35            65000          0

# %%
df_subset.sample(5)
df_subset
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(df_subset.iloc[:,:-1],df_subset.iloc[:,-1],test_size=0.3, random_state=42)

# X_train.shape, X_test.shape


x_train,x_test,y_train,y_test = train_test_split(df_subset.drop('Purchased',axis =1 ),df_subset['Purchased'],test_size=0.3, random_state=42)

x_train.shape, x_test.shape
# Out:
# ((280, 2), (120, 2))

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()


x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
scaler.mean_
# Out:
# array([3.75750000e+01, 7.05892857e+04])

# %%
x_train
# Out:
#      Age  EstimatedSalary
# 157   29            75000
# 109   38            80000
# 17    45            26000
# 347   54           108000
# 24    46            23000
# ..   ...              ...
# 71    24            27000
# 106   26            35000
# 270   43           133000
# 348   39            77000
# 102   32            86000
#
# [280 rows x 2 columns]

# %%
x_train_scaled
# Out:
# array([[-0.84252154,  0.1301563 ],
#        [ 0.04175763,  0.2777019 ],
#        [ 0.72953032, -1.31579061],
#        [ 1.61380949,  1.10395728],
#        [ 0.82778356, -1.40431797],
#        [-1.43204099, -1.25677236],
#        [-0.05649561,  0.1301563 ],
#        [ 0.43477059, -0.16493491],
#        [-0.2530021 ,  0.01211982],
#        [ 1.31904976,  2.22530386],
#        [ 0.14001087,  0.74984783],
#        [-1.33378775,  0.54328399],
#        [ 2.00682245,  0.72033871],
#        [-1.23553451, -1.43382709],
#        [ 0.33651735, -0.34198963],
#        [-0.94077478,  0.54328399],
#        [ 0.43477059,  0.2777019 ],
#        [ 0.43477059,  1.10395728],
#        [ 0.82778356,  0.74984783],
#        [ 0.9260368 ,  1.25150288],
#        [-0.44950858, -1.25677236],
#        [-1.82505395, -1.34529973],
#        [ 1.12254328,  0.54328399],
#        [-0.64601506, -1.64039093],
#        [-0.7442683 ,  0.24819278],
#        [ 1.02429004,  2.07775825],
#        [-0.54776182,  1.36953936],
# ...

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)
x_test_scaled = pd.DataFrame(x_test_scaled, columns = x_test.columns)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

ax1.scatter(x_train['Age'], x_train['EstimatedSalary'])
ax1.set_title("Before Scaling")
ax2.scatter(x_train_scaled['Age'], x_train_scaled['EstimatedSalary'],color='red')
ax2.set_title("After Scaling")
plt.show()
