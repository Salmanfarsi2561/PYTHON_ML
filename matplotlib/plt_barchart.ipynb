# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# BAR PLOT ------------------------------------------

# %%
x=["Python", "Java", "C++", "JavaScript", "Ruby"]
y=[50, 40, 30, 20, 10]

plt.bar(x,y,width=.4,color="black")

plt.xlabel("Programming Languages",fontsize=15)
plt.ylabel("popularity",fontsize=15)
plt.title("My first bar chart")
# Out:
# Text(0.5, 1.0, 'My first bar chart')

# %%
x=["Python", "Java", "C++", "JavaScript", "Ruby"]
y=[50, 40, 30, 20, 10]

c=["g","r","b","r","r"]
plt.bar(x,y,width=.4,color=c)

plt.xlabel("Programming Languages",fontsize=15)
plt.ylabel("popularity",fontsize=15)
plt.title("My first bar chart")
# Out:
# Text(0.5, 1.0, 'My first bar chart')

# %%
x=["Python", "Java", "C++", "JavaScript", "Ruby"]
y=[50, 40, 30, 20, 10]

c=["g","r","b","r","r"]
plt.bar(x,y,width=.4,color=c,edgecolor="black", linewidth=2,alpha=.5)

plt.xlabel("Programming Languages",fontsize=15)
plt.ylabel("popularity",fontsize=15)
plt.title("My first bar chart")
# Out:
# Text(0.5, 1.0, 'My first bar chart')

# %%
x=["Python", "Java", "C++", "JavaScript", "Ruby"]
y=[50, 40, 30, 20, 10]

c=["g","r","b","r","r"]
plt.bar(x,y,width=.4,color=c,label="PLOT LABLE")

plt.xlabel("This is X Label",fontsize=15)
plt.ylabel("This is Y Label",fontsize=15)
plt.title("My first bar chart:Title")

plt.legend(loc="upper right", fontsize=15) #label=legend

# %% [markdown]
# Creating Multiple Bar Charts................................................

# %%
#Composing 2 bar charts in single one.

x=["Python", "Java", "C++", "JavaScript", "Ruby"]
y=[85, 70, 60, 82, 10]

x1=["Python", "Java", "C++", "JavaScript", "Ruby"]
y1=[10, 20, 30, 40, 50]


plt.bar(x,y,width=.4,color="yellow",label="PLOT LABLE")
plt.bar(x1,y1,width=.4,color="red",label="PLOT LABLE 2")


plt.xlabel("This is X Label",fontsize=15)
plt.ylabel("This is Y Label",fontsize=15)
plt.title("My first bar chart:Title")

plt.legend(loc="upper center", fontsize=10) #label=legend

# %%
#Plotting bar side by side


x=["Python", "Java", "C++", "JavaScript", "Ruby"]
y=[85, 70, 60, 82, 10]


y1=[10, 20, 30, 40, 50]

p=np.arange(len(x)) #position of bars 
p1=[j+0.4 for j in p] #position of bars


plt.bar(p,y,width=.4,color="yellow",label="PLOT LABLE")
plt.bar(p1,y1,width=.4,color="red",label="PLOT LABLE 2")


plt.xlabel("This is X Label",fontsize=15)
plt.ylabel("This is Y Label",fontsize=15)
plt.title("My first bar chart:Title")

plt.legend(loc="upper center", fontsize=10) #label=legend

# %%
#More conventional way of plotting bar charts side by side, i added 0.4 to the position of the first bar chart to make it side by side
years =np.arange(2012,2015)

value1=[10,20,30]
value2=[20,30,40]

plt.bar(years,value1,width=.2,color="yellow",label="PLOT LABLE")
plt.bar(years+0.4,value2,width=.2,color="red",label="PLOT LABLE 2")
plt.xlabel("This is X Label",fontsize=15)
plt.ylabel("This is Y Label",fontsize=15)
# Out:
# Text(0, 0.5, 'This is Y Label')

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# Seaborn Basic

# %%
data = sns.load_dataset("titanic")
data.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.countplot(data=data,x="sex",)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=data,y="sex")
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(data=data,y='sex',hue='alive')
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
data= sns.load_dataset("exercise")
data.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.histplot(data=data,x="pulse")
# Out:
# <Axes: xlabel='pulse', ylabel='Count'>

# %%
sns.boxplot(data=data,x="pulse",y='time')
# Out:
# <Axes: xlabel='pulse', ylabel='time'>

# %%
sns.boxenplot(data=data,x="pulse")
# Out:
# <Axes: xlabel='pulse'>

# %%
sns.violinplot(data=data,x="pulse",y='time')
# Out:
# <Axes: xlabel='pulse', ylabel='time'>

# %%
sns.rugplot(data=data,x="pulse",y='time')
# Out:
# <Axes: xlabel='pulse', ylabel='time'>

# %%
sns.kdeplot(data=data,x="pulse",fill=True)
# Out:
# <Axes: xlabel='pulse', ylabel='Density'>

# %%
sns.stripplot(data=data,x="pulse")
# Out:
# <Axes: xlabel='pulse'>

# %%
sns.swarmplot(data=data,x="pulse")
# Out:
# <Axes: xlabel='pulse'>

# %%
sns.ecdfplot(data=data,x="pulse")
# Out:
# <Axes: xlabel='pulse', ylabel='Proportion'>

# %%
sns.ecdfplot(data=data,x="pulse",hue='diet')
# Out:
# <Axes: xlabel='pulse', ylabel='Proportion'>

# %%
sns.kdeplot(data=data,x="pulse",hue='diet')
sns.rugplot(data=data,x="pulse",hue='diet')
# Out:
# <Axes: xlabel='pulse', ylabel='Density'>

# %%
data = sns.load_dataset("flights")
data.head(5)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(data=data,x="year",y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.pointplot(data=data,x="year",y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.barplot(data=data,x="year",y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
data=sns.load_dataset("diamonds")
data.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data=data.sample(3000)

# %%
sns.scatterplot(data=data,x='carat',y='price')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.scatterplot(data=data,x="carat",y="price",marker='+')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.kdeplot(data=data,x="carat",y="price")
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.kdeplot(data=data,x="carat",y="price",fill=True,cmap='mako_r')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.histplot(data=data,x="carat",y="price",cmap='mako_r')
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.histplot(data=data,x="carat",y="price",color='red')
sns.kdeplot(data=data,x="carat",y="price",fill=False,cmap="coolwarm")
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.jointplot(data=data,x="carat",y="price",kind='hex')

# %%
sns.lmplot(data=data,x="carat",y="price",hue='cut')
